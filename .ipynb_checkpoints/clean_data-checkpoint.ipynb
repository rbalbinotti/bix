# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport
# Out:
# Pandas backend loaded 1.4.2
# Numpy backend loaded 1.21.5
# Pyspark backend NOT loaded
# Python backend loaded

# %%
sheet1 = pd.read_excel('Base de Dados - Questionário.xlsx', header=4, usecols=['ID', 'ProductID', 'ClientID', 'Discount', 'UnitPrice', 'Quantity', 'StoreID', 'Date'])

# %%
sheet1.head()
# Out:
#                                  ID                          ProductID  \
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
#
#    ClientID  Discount  UnitPrice  Quantity  StoreID       Date
# 0     14001      0.08      249.2         1        4 2018-12-10
# 1     14001      0.10      162.4         1        4 2019-04-25
# 2     14001      0.10      194.6         1        4 2019-07-17
# 3     14002      0.10      201.6         2        1 2018-04-10
# 4     14002      0.10      406.0         1        1 2019-01-21

# %%
sheet1.shape
# Out:
# (32753, 8)

# %%
sheet2 = pd.read_excel('Base de Dados - Questionário.xlsx', sheet_name=2)

# %%
sheet2.rename(columns={'ID': 'ProductID', 'Name': 'ProductName', 'Size': 'ProductSize'}, inplace=True)

# %%
sheet2.head()
# Out:
#                            ProductID      ProductName ProductSize
# 0  00066f42aeeb9f3007548bb9d3f33c381  Capitão América           P
# 1  00066f42aeeb9f3007548bb9d3f33c382  Capitão América           M
# 2  00066f42aeeb9f3007548bb9d3f33c383  Capitão América           G
# 3  00088930e925c41fd95ebfe695fd26551             Thor           P
# 4  00088930e925c41fd95ebfe695fd26552             Thor           M

# %%
sheet2.shape
# Out:
# (73, 3)

# %%
sheet3 = pd.read_excel('Base de Dados - Questionário.xlsx', sheet_name=3)

# %%
sheet3.rename(columns={'ID': 'ClientID'}, inplace=True)

# %%
sheet3.head()
# Out:
#    ClientID            City State DateOfBirth     Sex
# 0     14001        Curitiba    PR  1985-06-28   Homem
# 1     14002   Florianópolis    SC  1987-01-10   Homem
# 2     14003  Rio de Janeiro    RJ  1979-11-05   Homem
# 3     14004  Rio de Janeiro    RJ  1983-11-25  Mulher
# 4     14005   Florianópolis    SC  1969-04-07   Homem

# %%
sheet3.shape
# Out:
# (13650, 5)

# %%
sheet3.State.unique()
# Out:
# array(['PR', 'SC', 'RJ', 'SP', 'RS', 'MG', 'GO', 'MT', 'BH', 'ES', 'MA',
#        'BA', 'RR', 'RN', 'PA', 'RO', 'MS', 'AC'], dtype=object)

# %%
sheet3.City = sheet3.City.str.strip().str.title().str.replace('Aguia', 'Águia')\
.str.replace('ao', 'ão').str.replace('D', 'd').str.replace('du', 'Du').str.replace('alegre', 'Alegre')\
.str.replace('Caca', 'Caça').str.replace('GanDu', 'Gandu')

# %%
sheet3.City.sort_values().unique()
# Out:
# array(['Alto Paraiso de Goias', 'Ananindeua', 'Aracitaba', 'Araguari',
#        'Araraquara', 'Araxa', 'Aruja', 'Balneario Camboriu', 'Barbacena',
#        'Barra do Corda', 'Barueri', 'Bauru', 'Belo Horizonte', 'Betim',
#        'Birigui', 'Boa Vista', 'Botucatu', 'Braganca Paulista',
#        'Brumadinho', 'Cabo Frio', 'Cachoeira do Sul', 'Campinas',
#        'Campo Grande', 'Capitolio', 'Capão da Canoa', 'Carapicuiba',
#        'Caxias do Sul', 'Caçador', 'Caçapava', 'Contagem', 'Cubatão',
#        'Cuiaba', 'Curitiba', 'Duque de Caxias', 'Florianópolis', 'Franca',
#        'Gandu', 'Goiania', 'Governador Valadares', 'Guacui', 'Guarulhos',
#        'Hortolandia', 'Ibirama', 'Ijui', 'Itajobi', 'Itapetininga',
#        'Itapeva', 'Itaquaquecetuba', 'Itarare', 'Japeri',
#        'Jaragua do Sul', 'Juiz de Fora', 'Jundiai', 'Londrina',
#        'Louveira', 'Macaiba', 'Marica', 'Maua', 'Mesquita',
#        'Miguel Pereira', 'Miracema', 'Mogi das Cruzes', 'Monte Mor',
# ...

# %%
sheet3.City.sort_values().nunique()
# Out:
# 119

# %%
sheet4 = pd.read_excel('Base de Dados - Questionário.xlsx', sheet_name=4)

# %%
sheet4.rename(columns={'Name': 'City', 'ID': 'CityID'}, inplace=True)

# %%
sheet4.head(20)
# Out:
#    CityID            City State
# 0       1   Florianópolis    SC
# 1       2  Rio de Janeiro    RJ
# 2       3    Porto Alegre    RS
# 3       4        Curitiba    PR
# 4       7       São Paulo    SP
# 5       9  Belo Horizonte    MG
# 6      22          Online    BR

# %%
join_1 = pd.merge(sheet1, sheet2, on='ProductID', how='left')

# %%
join_1.head()
# Out:
#                                  ID                          ProductID  \
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
#
#    ClientID  Discount  UnitPrice  Quantity  StoreID       Date  \
# 0     14001      0.08      249.2         1        4 2018-12-10
# 1     14001      0.10      162.4         1        4 2019-04-25
# 2     14001      0.10      194.6         1        4 2019-07-17
# 3     14002      0.10      201.6         2        1 2018-04-10
# 4     14002      0.10      406.0         1        1 2019-01-21
#
#        ProductName ProductSize
# 0       Tempestade           G
# 1           Thanos           G
# 2  Capitão América           P
# ...

# %%
join_1.shape
# Out:
# (32753, 10)

# %%
join_2 = pd.merge(join_1, sheet3, on='ClientID', how='left')

# %%
join_2.head()
# Out:
#                                  ID                          ProductID  \
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
#
#    ClientID  Discount  UnitPrice  Quantity  StoreID       Date  \
# 0     14001      0.08      249.2         1        4 2018-12-10
# 1     14001      0.10      162.4         1        4 2019-04-25
# 2     14001      0.10      194.6         1        4 2019-07-17
# 3     14002      0.10      201.6         2        1 2018-04-10
# 4     14002      0.10      406.0         1        1 2019-01-21
#
#        ProductName ProductSize           City State DateOfBirth    Sex
# 0       Tempestade           G       Curitiba    PR  1985-06-28  Homem
# ...

# %%
join_2.shape
# Out:
# (32753, 14)

# %%
df = pd.merge(join_2, sheet4, on=['State', 'City'], how='left')

# %%
df.head()
# Out:
#                                  ID                          ProductID  \
# 0  80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1  3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2  f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3  7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4  76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
#
#    ClientID  Discount  UnitPrice  Quantity  StoreID       Date  \
# 0     14001      0.08      249.2         1        4 2018-12-10
# 1     14001      0.10      162.4         1        4 2019-04-25
# 2     14001      0.10      194.6         1        4 2019-07-17
# 3     14002      0.10      201.6         2        1 2018-04-10
# 4     14002      0.10      406.0         1        1 2019-01-21
#
#        ProductName ProductSize           City State DateOfBirth    Sex  CityID
# 0       Tempestade           G       Curitiba    PR  1985-06-28  Homem     4.0
# ...

# %%
df.shape
# Out:
# (32753, 15)

# %%
df.count()
# Out:
# ID             32753
# ProductID      32753
# ClientID       32753
# Discount       32753
# UnitPrice      32753
# Quantity       32753
# StoreID        32753
# Date           32753
# ProductName    32753
# ProductSize    32753
# City           32753
# State          32753
# DateOfBirth    32753
# Sex            32753
# CityID         31456
# dtype: int64

# %%
df[df['CityID'].isnull()]
# Out:
#                                      ID                          ProductID  \
# 33     513ce9adddd9478074b801c06baa35d7  0011c512eb256aa0dbbb544d8dffcf6e3
# 34     ad49f229e233b39202eb79fdc1877074  0021a87d4997a48b6cef1665602be0f51
# 35     e96a4c3bfb4afc0cb895a76f5ba0440b  0030e635639c898b323826589761cf233
# 36     efd8d1b981913fbc82d5cb85e7e0373f  002159fe700ed3521f46cfcf6e941c763
# 37     2f9d4ee8ca77fe0951ebfe9064cad953  002159fe700ed3521f46cfcf6e941c763
# ...                                 ...                                ...
# 32671  9fe7878dd156cead30e4d3005fb93de7  0021a87d4997a48b6cef1665602be0f51
# 32672  d0c925dd85481e3b99bbc725dc56e1a9  001c5d71ac6ad696d22315953758fa043
# 32673  ef1003827eb818ccc2c41557e21b2aec  00066f42aeeb9f3007548bb9d3f33c383
# 32674  490e475128481b0ccedaa812af721e53  003128f981470c3e5a2e7445e4a771cd1
# 32741  71035ba1aacb91b34786a7c4647e6486  0009406fd7479715e4bef61dd91f24623
#
# ...

# %%
query_bh = df.query('City == "Belo Horizonte" and CityID != 9')

# %%
query_bh.shape
# Out:
# (832, 15)

# %%
query_bh.head(2)
# Out:
#                                    ID                          ProductID  \
# 319  350885c9ea4a1a48519246d7ea5518ea  002af88741ba70c7b5cf4e4a0ad7ef853
# 320  40017beea749da112967b0049f098acb  001795ec6f1b187d37335e1c4704762e3
#
#      ClientID  Discount  UnitPrice  Quantity  StoreID       Date  \
# 319     14127      0.10      134.4         1       22 2019-01-20
# 320     14127      0.08      148.4         1       22 2019-06-01
#
#           ProductName ProductSize            City State DateOfBirth    Sex  \
# 319     Dragon Ball Z           G  Belo Horizonte    BH  1969-09-03  Homem
# 320  Mulher-Maravilha           G  Belo Horizonte    BH  1969-09-03  Homem
#
#      CityID
# 319     NaN
# 320     NaN

# %%
df.query('State == "BH" & City == "Belo Horizonte" & CityID != 9')
# Out:
#                                      ID                          ProductID  \
# 319    350885c9ea4a1a48519246d7ea5518ea  002af88741ba70c7b5cf4e4a0ad7ef853
# 320    40017beea749da112967b0049f098acb  001795ec6f1b187d37335e1c4704762e3
# 321    616e6d0ca11adb3e6d834612726f67f0  0021a87d4997a48b6cef1665602be0f53
# 322    4547e931fe370c3853e4afebc234811a  00088930e925c41fd95ebfe695fd26551
# 323    51efa345a1180ca3879442a31b0a265a  002d4ea7c04739c130bb74d7e7cd16943
# ...                                 ...                                ...
# 32671  9fe7878dd156cead30e4d3005fb93de7  0021a87d4997a48b6cef1665602be0f51
# 32672  d0c925dd85481e3b99bbc725dc56e1a9  001c5d71ac6ad696d22315953758fa043
# 32673  ef1003827eb818ccc2c41557e21b2aec  00066f42aeeb9f3007548bb9d3f33c383
# 32674  490e475128481b0ccedaa812af721e53  003128f981470c3e5a2e7445e4a771cd1
# 32741  71035ba1aacb91b34786a7c4647e6486  0009406fd7479715e4bef61dd91f24623
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32753 entries, 0 to 32752
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           32753 non-null  object
#  1   ProductID    32753 non-null  object
#  2   ClientID     32753 non-null  int64
#  3   Discount     32753 non-null  float64
#  4   UnitPrice    32753 non-null  float64
#  5   Quantity     32753 non-null  int64
#  6   StoreID      32753 non-null  int64
#  7   Date         32753 non-null  datetime64[ns]
#  8   ProductName  32753 non-null  object
#  9   ProductSize  32753 non-null  object
#  10  City         32753 non-null  object
#  11  State        32753 non-null  object
#  12  DateOfBirth  32753 non-null  datetime64[ns]
#  13  Sex          32753 non-null  object
#  14  CityID       31456 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(7)
# memory usage: 4.0+ MB

# %%
df['State'] = df['State'].replace('BH', 'MG')

# %%
df.CityID = df.StoreID.copy()

# %%
df.loc[32:50]
# Out:
#                                   ID                          ProductID  \
# 32  d4daa9ee1fe28458773297759dbfe2bc  002959d7a0b0990fe2d69988affcbc803
# 33  513ce9adddd9478074b801c06baa35d7  0011c512eb256aa0dbbb544d8dffcf6e3
# 34  ad49f229e233b39202eb79fdc1877074  0021a87d4997a48b6cef1665602be0f51
# 35  e96a4c3bfb4afc0cb895a76f5ba0440b  0030e635639c898b323826589761cf233
# 36  efd8d1b981913fbc82d5cb85e7e0373f  002159fe700ed3521f46cfcf6e941c763
# 37  2f9d4ee8ca77fe0951ebfe9064cad953  002159fe700ed3521f46cfcf6e941c763
# 38  1ab592bcd5d82491578a95e113886d3c  00088930e925c41fd95ebfe695fd26552
# 39  f89a86148310b5d6a02fbab8f1c9fb77  002959d7a0b0990fe2d69988affcbc803
# 40  fca018a47e2170d1f13529d7542d6438  001b237c0e9bb435f2e54071129237e93
# 41  b9c0b1f4d54b647c2de2b065bf82adaa  0021a87d4997a48b6cef1665602be0f53
# 42  85647e1ff3e4b10814f375af01c38836  002d4ea7c04739c130bb74d7e7cd16943
# 43  c456339d894d329ad45d39e3d6796b90  0011c512eb256aa0dbbb544d8dffcf6e1
# ...

# %%
df.CityID.unique()
# Out:
# array([ 4,  1,  2,  7,  3,  9, 22])

# %%
df.StoreID.unique()
# Out:
# array([ 4,  1,  2,  7,  3,  9, 22])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32753 entries, 0 to 32752
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           32753 non-null  object
#  1   ProductID    32753 non-null  object
#  2   ClientID     32753 non-null  int64
#  3   Discount     32753 non-null  float64
#  4   UnitPrice    32753 non-null  float64
#  5   Quantity     32753 non-null  int64
#  6   StoreID      32753 non-null  int64
#  7   Date         32753 non-null  datetime64[ns]
#  8   ProductName  32753 non-null  object
#  9   ProductSize  32753 non-null  object
#  10  City         32753 non-null  object
#  11  State        32753 non-null  object
#  12  DateOfBirth  32753 non-null  datetime64[ns]
#  13  Sex          32753 non-null  object
#  14  CityID       32753 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int64(4), object(7)
# memory usage: 5.0+ MB

# %%
# profile = ProfileReport(df, title="BIX - Tabela de Vendas", explorative=True)

# %%
# profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-06-15 19:00:49.089429&quot;&gt;&lt;title&gt;BIX - Tabela de Vendas&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# df.to_excel('clean_data.xlsx', index=False)
