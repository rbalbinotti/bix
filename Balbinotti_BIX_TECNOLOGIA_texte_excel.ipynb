# %%
import pandas as pd
import numpy as np

# %% [markdown]
# LENDO ARQUIVO EXCEL

# %%
vendas = pd.read_excel('Base de Dados - Questionário.xlsx', header=3)
display(vendas)
# Out:
#        Unnamed: 0  Unnamed: 1                        Unnamed: 2  \
# 0             NaN         NaN                                ID
# 1             NaN         NaN  80260d682079b6090c8285b398c50d97
# 2             NaN         NaN  3275736da1234f55d52bdf09d86b93bc
# 3             NaN         NaN  f3513eec8f1434b5b7e04ddf3598df40
# 4             NaN         NaN  7180475b60fe6bbbde424d39704a1177
# ...           ...         ...                               ...
# 32749         NaN         NaN  b155e2a8589d40bc9c0381ee48e3204f
# 32750         NaN         NaN  abb71d0110c4be1a1a0c52f929cab4a3
# 32751         NaN         NaN  db9a034f34174edd577b9f64cc982952
# 32752         NaN         NaN  ee00fa5093eb96d8573403b382fb60a8
# 32753         NaN         NaN  56c87d433bb46c7862e35e791b1907fa
#
#                               Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                              ProductID   ClientID   Discount  UnitPrice
# ...

# %% [markdown]
# CONHECENDO O ARQUIVO

# %%
vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32754 entries, 0 to 32753
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  0 non-null      float64
#  2   Unnamed: 2  32754 non-null  object
#  3   Unnamed: 3  32754 non-null  object
#  4   Unnamed: 4  32754 non-null  object
#  5   Unnamed: 5  32754 non-null  object
#  6   Unnamed: 6  32754 non-null  object
#  7   Unnamed: 7  32754 non-null  object
#  8   Unnamed: 8  32754 non-null  object
#  9   Unnamed: 9  32754 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 2.5+ MB

# %%
vendas = vendas.drop(columns=['Unnamed: 0', 'Unnamed: 1'])

# %%
vendas.notnull().sum()
# Out:
# Unnamed: 2    32754
# Unnamed: 3    32754
# Unnamed: 4    32754
# Unnamed: 5    32754
# Unnamed: 6    32754
# Unnamed: 7    32754
# Unnamed: 8    32754
# Unnamed: 9    32754
# dtype: int64

# %% [markdown]
# LIMPANDO E ORGANIZANDO

# %%
vendas = vendas.rename(columns=vendas.iloc[0])

# %%
vendas
# Out:
#                                      ID                          ProductID  \
# 0                                    ID                          ProductID
# 1      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 2      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 3      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# ...                                 ...                                ...
# 32749  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32750  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32751  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32752  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32753  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
# ...

# %%
vendas_limpo = vendas.drop(index=[0])

# %%
display(vendas_limpo)
# Out:
#                                      ID                          ProductID  \
# 1      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 2      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 3      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 4      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 5      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32749  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32750  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32751  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32752  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32753  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
# ...

# %%
vendas_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32753 entries, 1 to 32753
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         32753 non-null  object
#  1   ProductID  32753 non-null  object
#  2   ClientID   32753 non-null  object
#  3   Discount   32753 non-null  object
#  4   UnitPrice  32753 non-null  object
#  5   Quantity   32753 non-null  object
#  6   StoreID    32753 non-null  object
#  7   Date       32753 non-null  object
# dtypes: object(8)
# memory usage: 2.2+ MB

# %% [markdown]
# LENDO OUTRAS PLANILHAS DO ARQUIVO

# %%
df = pd.read_excel('Base de Dados - Questionário.xlsx', sheet_name = [2, 3, 4], header=0)
produto = df[2]
cliente = df[3]
estado = df[4]

# %%
display(produto)
# Out:
#                                    ID             Name Size
# 0   00066f42aeeb9f3007548bb9d3f33c381  Capitão América    P
# 1   00066f42aeeb9f3007548bb9d3f33c382  Capitão América    M
# 2   00066f42aeeb9f3007548bb9d3f33c383  Capitão América    G
# 3   00088930e925c41fd95ebfe695fd26551             Thor    P
# 4   00088930e925c41fd95ebfe695fd26552             Thor    M
# ..                                ...              ...  ...
# 68  0030e635639c898b323826589761cf233       Rick Morty    G
# 69  003128f981470c3e5a2e7445e4a771cd1   Homer Simpsons    P
# 70  003128f981470c3e5a2e7445e4a771cd2   Homer Simpsons    M
# 71  003128f981470c3e5a2e7445e4a771cd3   Homer Simpsons    G
# 72  003128f981470c3e5a2e7445e4a771cd4   Homer Simpsons   GG
#
# [73 rows x 3 columns]

# %%
produto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      73 non-null     object
#  1   Name    73 non-null     object
#  2   Size    73 non-null     object
# dtypes: object(3)
# memory usage: 1.8+ KB

# %%
produto = produto.rename(columns = {'ID':'ProductID'})

# %%
display(cliente)
# Out:
#           ID            City State DateOfBirth     Sex
# 0      14001        Curitiba    PR  1985-06-28   Homem
# 1      14002   Florianópolis    SC  1987-01-10   Homem
# 2      14003  Rio de Janeiro    RJ  1979-11-05   Homem
# 3      14004  Rio de Janeiro    RJ  1983-11-25  Mulher
# 4      14005   Florianópolis    SC  1969-04-07   Homem
# ...      ...             ...   ...         ...     ...
# 13645  28689  Belo Horizonte    MG  1999-01-15   Homem
# 13646  28691  Belo Horizonte    BH  1956-02-07   Homem
# 13647  28692    Porto Alegre    RS  1985-10-19   Homem
# 13648  28694        Curitiba    PR  1982-10-22   Homem
# 13649  28695        Curitiba    PR  1961-10-24   Homem
#
# [13650 rows x 5 columns]

# %%
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13650 entries, 0 to 13649
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           13650 non-null  int64
#  1   City         13650 non-null  object
#  2   State        13650 non-null  object
#  3   DateOfBirth  13650 non-null  datetime64[ns]
#  4   Sex          13650 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 533.3+ KB

# %%
cliente = cliente.rename(columns = {'ID':'ClientID'})

# %%
display(estado)
# Out:
#    ID            Name State
# 0   1   Florianópolis    SC
# 1   2  Rio de Janeiro    RJ
# 2   3    Porto Alegre    RS
# 3   4        Curitiba    PR
# 4   7       São Paulo    SP
# 5   9  Belo Horizonte    MG
# 6  22          Online    BR

# %%
estado.notnull().sum()
# Out:
# ID       7
# Name     7
# State    7
# dtype: int64

# %%
estado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      7 non-null      int64
#  1   Name    7 non-null      object
#  2   State   7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# UNINDO TABELAS

# %%
# união das tabelas cliente estado
cliente_u = pd.merge(cliente, estado, how='left', on='State')

# %%
cliente_drop = cliente_u.drop(columns=['Name', 'ID'])
cliente_drop
# Out:
#        ClientID            City State DateOfBirth     Sex
# 0         14001        Curitiba    PR  1985-06-28   Homem
# 1         14002   Florianópolis    SC  1987-01-10   Homem
# 2         14003  Rio de Janeiro    RJ  1979-11-05   Homem
# 3         14004  Rio de Janeiro    RJ  1983-11-25  Mulher
# 4         14005   Florianópolis    SC  1969-04-07   Homem
# ...         ...             ...   ...         ...     ...
# 13645     28689  Belo Horizonte    MG  1999-01-15   Homem
# 13646     28691  Belo Horizonte    BH  1956-02-07   Homem
# 13647     28692    Porto Alegre    RS  1985-10-19   Homem
# 13648     28694        Curitiba    PR  1982-10-22   Homem
# 13649     28695        Curitiba    PR  1961-10-24   Homem
#
# [13650 rows x 5 columns]

# %%
df = pd.merge(vendas_limpo, produto, how='left', on=['ProductID'])
df
# Out:
#                                      ID                          ProductID  \
# 0      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32748  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32749  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32752  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
# ...

# %%
df = pd.merge(df, cliente_drop, how='left')
df
# Out:
#                                      ID                          ProductID  \
# 0      80260d682079b6090c8285b398c50d97  002552c0663708129c0019cc97552d7d3
# 1      3275736da1234f55d52bdf09d86b93bc  001b237c0e9bb435f2e54071129237e93
# 2      f3513eec8f1434b5b7e04ddf3598df40  00066f42aeeb9f3007548bb9d3f33c381
# 3      7180475b60fe6bbbde424d39704a1177  001b72dfd63e9833e8c02742adf472e33
# 4      76600853a200fe87e141adae6b35674c  00210e41887c2a8ef9f791ebc780cc363
# ...                                 ...                                ...
# 32748  b155e2a8589d40bc9c0381ee48e3204f  002ec297b1b00fb9dde7ee6ac24b67712
# 32749  abb71d0110c4be1a1a0c52f929cab4a3  002d4ea7c04739c130bb74d7e7cd16943
# 32750  db9a034f34174edd577b9f64cc982952  001795ec6f1b187d37335e1c4704762e3
# 32751  ee00fa5093eb96d8573403b382fb60a8  002ec297b1b00fb9dde7ee6ac24b67713
# 32752  56c87d433bb46c7862e35e791b1907fa  0009406fd7479715e4bef61dd91f24622
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32753 entries, 0 to 32752
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           32753 non-null  object
#  1   ProductID    32753 non-null  object
#  2   ClientID     32753 non-null  object
#  3   Discount     32753 non-null  object
#  4   UnitPrice    32753 non-null  object
#  5   Quantity     32753 non-null  object
#  6   StoreID      32753 non-null  object
#  7   Date         32753 non-null  object
#  8   Name         32753 non-null  object
#  9   Size         32753 non-null  object
#  10  City         32753 non-null  object
#  11  State        32753 non-null  object
#  12  DateOfBirth  32753 non-null  datetime64[ns]
#  13  Sex          32753 non-null  object
# dtypes: datetime64[ns](1), object(13)
# memory usage: 3.7+ MB

# %%
df.to_excel('BIX_TECNOLOGIA_DF.xlsx')

# %%
#t = df.groupby(['State']).count().sort_values('State')
t
# Out:
#          ID  ProductID  ClientID  Discount  UnitPrice  Quantity  StoreID  \
# State
# AC        8          8         8         8          8         8        8
# BA        6          6         6         6          6         6        6
# BH      832        832       832       832        832       832      832
# ES       19         19        19        19         19        19       19
# GO        6          6         6         6          6         6        6
# MA        6          6         6         6          6         6        6
# MG     1845       1845      1845      1845       1845      1845     1845
# MS        4          4         4         4          4         4        4
# MT       18         18        18        18         18        18       18
# PA        1          1         1         1          1         1        1
# PR     5172       5172      5172      5172       5172      5172     5172
# RJ     6838       6838      6838      6838       6838      6838     6838
# ...
